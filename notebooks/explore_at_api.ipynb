# %%
import os
import requests

API_KEY = os.getenv("AT_API_KEY")
url = "https://api.at.govt.nz/realtime/legacy/vehiclelocations"
headers = {"Ocp-Apim-Subscription-Key": API_KEY}

response = requests.get(url, headers=headers)
print(response.status_code)
print(response.content[:200])
# Out:
# 200
# b'{"status":"OK","response":{"header":{"timestamp":1774394812.07,"gtfs_realtime_version":"1.0","incrementality":0},"entity":[{"id":"563168600","vehicle":{"position":{"latitude":-36.71899166666667,"longi'

# %%
data = response.json()

print(data.keys())
print(data["response"]["header"])

entities = data["response"]["entity"]
print(f"In total of{len(entities)} vehicles")
print(entities[0])
# Out:
# dict_keys(['status', 'response', 'error'])
# {'timestamp': 1774394812.07, 'gtfs_realtime_version': '1.0', 'incrementality': 0}
# In total of1579 vehicles
# {'id': '563168600', 'vehicle': {'position': {'latitude': -36.71899166666667, 'longitude': 174.87243, 'bearing': '62', 'speed': 0.3086664}, 'timestamp': 1774394747, 'vehicle': {'id': '563168600', 'label': '', 'license_plate': ''}}, 'is_deleted': False}
